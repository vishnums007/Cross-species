# %% [markdown]
# Welcome to the first step of cross species analysis using the saturn package. Before starting this step you need to have your anndatas ready and saved in the folder called "data". Use the Rscript to convert your seurat object to anndata, if you haven't done already.

# %% [markdown]
# #### All combined

# %%
# !ls
# Out:
# cross_species_cell_type_map.csv  S1_Mutlipleseeds.ipynb
# Mouse_SC.h5ad			 zebrafish_mouse_run.csv
# multiple_seed_results		 Zebrafish_SC.h5ad

# %% [markdown]
# ### Making CSV file for running Saturn

# %% [markdown]
# This csv file contains information about the path to dataset that we need to integrate as well as the the path pytorch trained protein embedding for the respective species. You can either directly edit the csv file or use the following codes to create one.

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=["path", "species", "embedding_path"])
df["species"]=["zebrafish", "mouse"]
df["path"] = ["/DATAFILES/Cross_species/Fulldatasets/Allcombined/Zebrafish_SC.h5ad", "/DATAFILES/Cross_species/Fulldatasets/Allcombined/Mouse_SC.h5ad"]

zebrafish_embedding_path = "/DATAFILES/Cross_species/protein_embeddings/ESM2/zebrafish_embedding.torch"
mouse_embedding_path = "/DATAFILES/Cross_species/protein_embeddings/ESM2/mouse_embedding.torch"

df["embedding_path"] = [zebrafish_embedding_path, mouse_embedding_path]
df.to_csv("zebrafish_mouse_run.csv", index=False)
df
# Out:
#                                                 path    species  \
# 0  /DATAFILES/Cross_species/Fulldatasets/Allcombi...  zebrafish
# 1  /DATAFILES/Cross_species/Fulldatasets/Allcombi...      mouse
#
#                                       embedding_path
# 0  /DATAFILES/Cross_species/protein_embeddings/ES...
# 1  /DATAFILES/Cross_species/protein_embeddings/ES...

# %%
import scanpy as sc

# %%
zebra=sc.read_h5ad("/DATAFILES/Cross_species/Fulldatasets/Allcombined/Zebrafish_SC.h5ad")

# %%
zebra.obs["cell_type"].unique()
# Out:
# array(['MHM-Microglia', 'MHM-Neurons', 'MHM-Div-Myeloid',
#        'MHM-Macrophage', 'MHM-Ependymal', 'MHM-iNeurons', 'MHM-T Cells',
#        'MHM-Astrocytes', 'MHM-Oligodendrocytes', 'MHM-OPCs',
#        'MHM-Pericytes', 'MHM-Neutrophils'], dtype=object)

# %% [markdown]
# #### make sure that there are no underscores (_) in the celltype annotation. This will throw error later

# %%
mouse=sc.read_h5ad("/DATAFILES/Cross_species/Fulldatasets/Allcombined/Mouse_SC.h5ad")

# %%
mouse.obs["cell_type"].unique()
# Out:
# array(['Anderson-Oligodendrocytes', 'Anderson-OPC', 'Anderson-Astrocytes',
#        'Anderson-Vascular', 'Anderson-Microglia', 'Anderson-Neurons',
#        'JaeLee-Microglia', 'JaeLee-Ependymal', 'JaeLee-Endothelial',
#        'JaeLee-Immune', 'JaeLee-Astrocytes', 'JaeLee-Oligodendrocytes',
#        'JaeLee-Pericytes', 'JaeLee-OPCs', 'JaeLee-Div-Myeloid',
#        'ArielLevine-Oligodendrocytes', 'ArielLevine-Schwann',
#        'ArielLevine-Oligodendrocyte Progenitors/Precursors',
#        'ArielLevine-Neurons', 'ArielLevine-Microglia/Hematopoietic',
#        'ArielLevine-Endothelial', 'ArielLevine-Leptomeninges',
#        'ArielLevine-Ependymal', 'ArielLevine-Astrocytes',
#        'ArielLevine-Pericytes'], dtype=object)

# %% [markdown]
# ## Running multiple seeds of SATURN

# %% [markdown]
# Seed are used to initialize the centroid creation and dataloader. It is the seed used to generate random numbers.
# You don't need to run multiple seeds, however it can be useful to get a sense of the variance in integration results. You could then choose the seed that got the highest integration score if you want.

# %% [markdown]
# ### Running multiple seeds to identify the best integration

# %%
# !python3 /DATAFILES/Cross_species/SATURN/saturn_multiple_seeds_singlegpu.py \
--run=zebrafish_mouse_run.csv --embedding_model=ESM2 \
--seeds=25
# Out:
# ['0']
#   0%|                                                    | 0/25 [00:00<?, ?it/s]RUNNING SEED: 0 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.856510162353516, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.72it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.08it/s]
#   4%|█▍                                   | 1/25 [1:35:33<38:13:22, 5733.45s/it]RUNNING SEED: 1 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.11199951171875, Avg Loss mouse: 1624, Avg Lo
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.64it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.13it/s]
#   8%|██▉                                  | 2/25 [3:11:08<36:38:10, 5734.38s/it]RUNNING SEED: 2 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.910243034362793, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.68it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.48it/s]
#  12%|████▍                                | 3/25 [4:46:20<34:58:47, 5723.99s/it]RUNNING SEED: 3 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.899799346923828, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.86it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 26.99it/s]
#  16%|█████▉                               | 4/25 [6:22:05<33:26:19, 5732.37s/it]RUNNING SEED: 4 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.039613723754883, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.66it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.66it/s]
#  20%|███████▍                             | 5/25 [7:56:49<31:45:01, 5715.06s/it]RUNNING SEED: 5 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.161063194274902, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.79it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.19it/s]
#  24%|████████▉                            | 6/25 [9:32:46<30:14:14, 5729.20s/it]RUNNING SEED: 6 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.923015594482422, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.64it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.97it/s]
#  28%|██████████                          | 7/25 [11:08:10<28:38:18, 5727.71s/it]RUNNING SEED: 7 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.223584175109863, Avg Loss mouse: 1625, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.56it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.35it/s]
#  32%|███████████▌                        | 8/25 [12:43:48<27:03:45, 5730.92s/it]RUNNING SEED: 8 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.781561851501465, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.85it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.17it/s]
#  36%|████████████▉                       | 9/25 [14:18:58<25:26:29, 5724.35s/it]RUNNING SEED: 9 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.991299629211426, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.57it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.18it/s]
#  40%|██████████████                     | 10/25 [15:54:40<23:52:27, 5729.85s/it]RUNNING SEED: 10 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.188828468322754, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.80it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.91it/s]
#  44%|███████████████▍                   | 11/25 [17:30:00<22:16:12, 5726.60s/it]RUNNING SEED: 11 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.133615493774414, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.74it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.57it/s]
#  48%|████████████████▊                  | 12/25 [19:05:02<20:39:11, 5719.37s/it]RUNNING SEED: 12 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.1002779006958, Avg Loss mouse: 1624, Avg Los
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.75it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.19it/s]
#  52%|██████████████████▏                | 13/25 [20:39:49<19:01:54, 5709.51s/it]RUNNING SEED: 13 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.125267028808594, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.75it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.89it/s]
#  56%|███████████████████▌               | 14/25 [22:15:03<17:27:00, 5710.93s/it]RUNNING SEED: 14 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.096527099609375, Avg Loss mouse: 1623, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.78it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.93it/s]
#  60%|█████████████████████              | 15/25 [23:50:13<15:51:46, 5710.62s/it]RUNNING SEED: 15 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.644179344177246, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.73it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.57it/s]
#  64%|██████████████████████▍            | 16/25 [25:26:23<14:19:16, 5728.46s/it]RUNNING SEED: 16 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.799846649169922, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.76it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.66it/s]
#  68%|███████████████████████▊           | 17/25 [27:01:57<12:43:59, 5729.92s/it]RUNNING SEED: 17 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.791257858276367, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.60it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.93it/s]
#  72%|█████████████████████████▏         | 18/25 [28:37:19<11:08:14, 5727.80s/it]RUNNING SEED: 18 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.888647079467773, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.77it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.54it/s]
#  76%|███████████████████████████▎        | 19/25 [30:12:57<9:33:04, 5730.82s/it]RUNNING SEED: 19 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.97371768951416, Avg Loss mouse: 1624, Avg Lo
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.66it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.11it/s]
#  80%|████████████████████████████▊       | 20/25 [31:48:25<7:57:29, 5729.98s/it]RUNNING SEED: 20 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.66200065612793, Avg Loss mouse: 1624, Avg Lo
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.60it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.53it/s]
#  84%|██████████████████████████████▏     | 21/25 [33:24:13<6:22:21, 5735.26s/it]RUNNING SEED: 21 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.913230895996094, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.78it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.65it/s]
#  88%|███████████████████████████████▋    | 22/25 [34:59:22<4:46:22, 5727.35s/it]RUNNING SEED: 22 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.123453140258789, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.61it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.60it/s]
#  92%|█████████████████████████████████   | 23/25 [36:34:45<3:10:52, 5726.13s/it]RUNNING SEED: 23 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 11.134138107299805, Avg Loss mouse: 1624, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.76it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:08<00:00, 27.94it/s]
#  96%|██████████████████████████████████▌ | 24/25 [38:09:57<1:35:21, 5721.82s/it]RUNNING SEED: 24 ON GPU:0
# Epoch 200: L1 Loss 0.0 Rank Loss 10.869377136230469, Avg Loss mouse: 1625, Avg L
# 100%|█████████████████████████████████████████| 224/224 [00:17<00:00, 12.89it/s]
# 100%|█████████████████████████████████████████| 224/224 [00:07<00:00, 28.85it/s]
# 100%|██████████████████████████████████████| 25/25 [39:45:25<00:00, 5725.01s/it]

# %% [markdown]
# ### Scoring Multiple Seeds

# %% [markdown]
# Running multiple seeds enable us to select the best integration possible. For that, we  now need to score different seeds.

# %%
# !ls
# Out:
# cross_species_cell_type_map.csv  S1_Mutlipleseeds.ipynb
# Mouse_SC.h5ad			 zebrafish_mouse_run.csv
# multiple_seed_results		 Zebrafish_SC.h5ad

# %%
from glob import glob
fz_adatas = glob("multiple_seed_results/saturn_results/*ESM2*5000*8000*default*.h5ad")
fz_adatas
# Out:
# ['multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_0_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_0.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_1_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_1.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_2_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_2.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_3_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_3.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_4_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_4.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_5_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_5.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_6_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_6.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_7_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_7.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_8_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_8.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_9_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_9.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_10_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_10.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_11_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_11.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_12_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_12.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_13_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_13.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_14_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_14.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_15_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_15.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_16_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_16.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_17_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_17.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_18_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_18.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_19_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_19.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_20_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_20.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_21_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_21.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_22_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_22.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_23_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_23.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_24_pretrain.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_24.h5ad']

# %%
fz_adatas= [path for path in fz_adatas if "pretrain" not in path] # selecting out all pretrain files
fz_adatas
# Out:
# ['multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_0.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_1.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_2.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_3.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_4.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_5.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_6.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_7.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_8.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_9.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_10.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_11.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_12.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_13.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_14.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_15.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_16.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_17.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_18.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_19.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_20.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_21.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_22.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_23.h5ad',
#  'multiple_seed_results/saturn_results/test256_data_Mouse_SC_Zebrafish_SC_org_zebrafish_mouse_run_l1_0_pe_1.0_ESM2_macrogenes_5000_hv_genes_8000_centroid_score_func_default_seed_24.h5ad']

# %%
seeds = [path.split("_")[-1].replace(".h5ad", "") for path in fz_adatas]
fz_adatas, seeds

# creating a csv file with file path associated with each seed
import pandas as pd
score_df = pd.DataFrame()
score_df["seed"] = seeds
score_df["path"] = fz_adatas
display(score_df.head())
print(len(score_df))
score_df.to_csv("./multi_seeds.csv", index=False)
# Out:
#   seed                                               path
# 0    0  multiple_seed_results/saturn_results/test256_d...
# 1    1  multiple_seed_results/saturn_results/test256_d...
# 2    2  multiple_seed_results/saturn_results/test256_d...
# 3    3  multiple_seed_results/saturn_results/test256_d...
# 4    4  multiple_seed_results/saturn_results/test256_d...
# 25

# %%
# !python3 /DATAFILES/Cross_species/SATURN/score_adata.py --adata=multi_seeds.csv --scores=1 \
                                 --multiple_files --species1=zebrafish --species2=mouse --label=labels2 \
                                 --ct_map=cross_species_cell_type_map.csv
# Out:
# /DATAFILES/Cross_species/SATURN/score_adata.py:1060: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if species_1 or species_2 is "human":
# /DATAFILES/Cross_species/SATURN/score_adata.py:1065: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif species_1 or species_2 is "zebrafish":
# 0
# 100%|███████████████████████████████████████████| 25/25 [01:41<00:00,  4.05s/it]
# 100%|███████████████████████████████████████████| 25/25 [02:24<00:00,  5.78s/it]
# multi_seeds_scores.csv
#     seed  ...               Label
# 0      0  ...  zebrafish to mouse
# 1      1  ...  zebrafish to mouse
# 2      2  ...  zebrafish to mouse
# 3      3  ...  zebrafish to mouse
# 4      4  ...  zebrafish to mouse
# 5      5  ...  zebrafish to mouse
# 6      6  ...  zebrafish to mouse
# 7      7  ...  zebrafish to mouse
# 8      8  ...  zebrafish to mouse
# 9      9  ...  zebrafish to mouse
# 10    10  ...  zebrafish to mouse
# 11    11  ...  zebrafish to mouse
# 12    12  ...  zebrafish to mouse
# 13    13  ...  zebrafish to mouse
# 14    14  ...  zebrafish to mouse
# 15    15  ...  zebrafish to mouse
# 16    16  ...  zebrafish to mouse
# 17    17  ...  zebrafish to mouse
# 18    18  ...  zebrafish to mouse
# 19    19  ...  zebrafish to mouse
# 20    20  ...  zebrafish to mouse
# 21    21  ...  zebrafish to mouse
# 22    22  ...  zebrafish to mouse
# 23    23  ...  zebrafish to mouse
# 24    24  ...  zebrafish to mouse
# 0      0  ...  mouse to zebrafish
# 1      1  ...  mouse to zebrafish
# 2      2  ...  mouse to zebrafish
# 3      3  ...  mouse to zebrafish
# 4      4  ...  mouse to zebrafish
# 5      5  ...  mouse to zebrafish
# 6      6  ...  mouse to zebrafish
# 7      7  ...  mouse to zebrafish
# 8      8  ...  mouse to zebrafish
# 9      9  ...  mouse to zebrafish
# 10    10  ...  mouse to zebrafish
# 11    11  ...  mouse to zebrafish
# 12    12  ...  mouse to zebrafish
# 13    13  ...  mouse to zebrafish
# 14    14  ...  mouse to zebrafish
# 15    15  ...  mouse to zebrafish
# 16    16  ...  mouse to zebrafish
# 17    17  ...  mouse to zebrafish
# 18    18  ...  mouse to zebrafish
# 19    19  ...  mouse to zebrafish
# 20    20  ...  mouse to zebrafish
# 21    21  ...  mouse to zebrafish
# 22    22  ...  mouse to zebrafish
# 23    23  ...  mouse to zebrafish
# 24    24  ...  mouse to zebrafish
#
# [50 rows x 6 columns]

# %%
df = pd.read_csv("multi_seeds_scores.csv")
df = df.sort_values("Logistic Regression", ascending=False)
df
# Out:
#     seed                                               path  \
# 15    15  multiple_seed_results/saturn_results/test256_d...
# 39    14  multiple_seed_results/saturn_results/test256_d...
# 35    10  multiple_seed_results/saturn_results/test256_d...
# 18    18  multiple_seed_results/saturn_results/test256_d...
# 36    11  multiple_seed_results/saturn_results/test256_d...
# 46    21  multiple_seed_results/saturn_results/test256_d...
# 25     0  multiple_seed_results/saturn_results/test256_d...
# 37    12  multiple_seed_results/saturn_results/test256_d...
# 48    23  multiple_seed_results/saturn_results/test256_d...
# 29     4  multiple_seed_results/saturn_results/test256_d...
# 32     7  multiple_seed_results/saturn_results/test256_d...
# 47    22  multiple_seed_results/saturn_results/test256_d...
# 26     1  multiple_seed_results/saturn_results/test256_d...
# 7      7  multiple_seed_results/saturn_results/test256_d...
# 5      5  multiple_seed_results/saturn_results/test256_d...
# 14    14  multiple_seed_results/saturn_results/test256_d...
# 4      4  multiple_seed_results/saturn_results/test256_d...
# 21    21  multiple_seed_results/saturn_results/test256_d...
# 10    10  multiple_seed_results/saturn_results/test256_d...
# 17    17  multiple_seed_results/saturn_results/test256_d...
# 6      6  multiple_seed_results/saturn_results/test256_d...
# 2      2  multiple_seed_results/saturn_results/test256_d...
# 0      0  multiple_seed_results/saturn_results/test256_d...
# 22    22  multiple_seed_results/saturn_results/test256_d...
# 11    11  multiple_seed_results/saturn_results/test256_d...
# 23    23  multiple_seed_results/saturn_results/test256_d...
# 1      1  multiple_seed_results/saturn_results/test256_d...
# 12    12  multiple_seed_results/saturn_results/test256_d...
# 3      3  multiple_seed_results/saturn_results/test256_d...
# 16    16  multiple_seed_results/saturn_results/test256_d...
# 19    19  multiple_seed_results/saturn_results/test256_d...
# 13    13  multiple_seed_results/saturn_results/test256_d...
# 8      8  multiple_seed_results/saturn_results/test256_d...
# 38    13  multiple_seed_results/saturn_results/test256_d...
# 33     8  multiple_seed_results/saturn_results/test256_d...
# 40    15  multiple_seed_results/saturn_results/test256_d...
# 27     2  multiple_seed_results/saturn_results/test256_d...
# 28     3  multiple_seed_results/saturn_results/test256_d...
# 43    18  multiple_seed_results/saturn_results/test256_d...
# 30     5  multiple_seed_results/saturn_results/test256_d...
# 31     6  multiple_seed_results/saturn_results/test256_d...
# 41    16  multiple_seed_results/saturn_results/test256_d...
# 34     9  multiple_seed_results/saturn_results/test256_d...
# 42    17  multiple_seed_results/saturn_results/test256_d...
# 49    24  multiple_seed_results/saturn_results/test256_d...
# 9      9  multiple_seed_results/saturn_results/test256_d...
# 24    24  multiple_seed_results/saturn_results/test256_d...
# 20    20  multiple_seed_results/saturn_results/test256_d...
# 44    19  multiple_seed_results/saturn_results/test256_d...
# 45    20  multiple_seed_results/saturn_results/test256_d...
#
#     Logistic Regression  Balanced Regression  Reannotation               Label
# 15             0.392334             0.205905           NaN  zebrafish to mouse
# 39             0.384001             0.332830           NaN  mouse to zebrafish
# 35             0.378225             0.328388           NaN  mouse to zebrafish
# 18             0.330539             0.176424           NaN  zebrafish to mouse
# 36             0.270255             0.249713           NaN  mouse to zebrafish
# 46             0.269339             0.249120           NaN  mouse to zebrafish
# 25             0.268961             0.248644           NaN  mouse to zebrafish
# 37             0.267874             0.249013           NaN  mouse to zebrafish
# 48             0.267618             0.249251           NaN  mouse to zebrafish
# 29             0.267593             0.248629           NaN  mouse to zebrafish
# 32             0.267495             0.249020           NaN  mouse to zebrafish
# 47             0.267410             0.247582           NaN  mouse to zebrafish
# 26             0.266763             0.247758           NaN  mouse to zebrafish
# 7              0.254152             0.173464           NaN  zebrafish to mouse
# 5              0.254091             0.171470           NaN  zebrafish to mouse
# 14             0.253825             0.163608           NaN  zebrafish to mouse
# 4              0.253812             0.168960           NaN  zebrafish to mouse
# 21             0.253587             0.158612           NaN  zebrafish to mouse
# 10             0.253478             0.160219           NaN  zebrafish to mouse
# 17             0.253334             0.161908           NaN  zebrafish to mouse
# 6              0.252885             0.154427           NaN  zebrafish to mouse
# 2              0.252496             0.159547           NaN  zebrafish to mouse
# 0              0.252278             0.150915           NaN  zebrafish to mouse
# 22             0.252237             0.137818           NaN  zebrafish to mouse
# 11             0.251392             0.127907           NaN  zebrafish to mouse
# 23             0.251358             0.121380           NaN  zebrafish to mouse
# 1              0.251174             0.121680           NaN  zebrafish to mouse
# 12             0.251051             0.122762           NaN  zebrafish to mouse
# 3              0.250642             0.123044           NaN  zebrafish to mouse
# 16             0.248087             0.124145           NaN  zebrafish to mouse
# 19             0.221854             0.126263           NaN  zebrafish to mouse
# 13             0.221139             0.101650           NaN  zebrafish to mouse
# 8              0.220096             0.080807           NaN  zebrafish to mouse
# 38             0.194547             0.165616           NaN  mouse to zebrafish
# 33             0.194290             0.165545           NaN  mouse to zebrafish
# 40             0.165521             0.278005           NaN  mouse to zebrafish
# 27             0.124931             0.114604           NaN  mouse to zebrafish
# 28             0.098958             0.170345           NaN  mouse to zebrafish
# 43             0.094050             0.170284           NaN  mouse to zebrafish
# 30             0.090777             0.167663           NaN  mouse to zebrafish
# 31             0.090716             0.167512           NaN  mouse to zebrafish
# 41             0.090557             0.167316           NaN  mouse to zebrafish
# 34             0.088958             0.166684           NaN  mouse to zebrafish
# 42             0.088628             0.164531           NaN  mouse to zebrafish
# 49             0.073559             0.083647           NaN  mouse to zebrafish
# 9              0.047278             0.085790           NaN  zebrafish to mouse
# 24             0.032250             0.074407           NaN  zebrafish to mouse
# 20             0.023125             0.099225           NaN  zebrafish to mouse
# 44             0.018097             0.083417           NaN  mouse to zebrafish
# 45             0.010514             0.058030           NaN  mouse to zebrafish

# %% [markdown]
# It looks like seed # 14 got the highest value in both logistic regression and balanced regression. So, I will select the anndata output from seed # 14 for downstream analysis

# %% [markdown]
# Now, please use the scanpy_analysis.py file for further downstream analysis of the downstream output files for seed#6

# %%
df.to_csv("Allcombined_seed_Scores.csv", index=False)
